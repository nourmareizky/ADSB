# %%
import tweepy
import pandas as pd

# %%
TWITTER_CONSUMER_KEY = ''

TWITTER_CONSUMER_SECRET = ''

TWITTER_ACCESS_TOKEN = ''

TWITTER_ACCESS_TOKEN_SECRET = ''

# %%
class MyStreamListener(tweepy.StreamListener):

    def on_status(self, status):
        print(status.text)
    def on_error(self, status_code):
        if status_code == 420:
            #returning False in on_error disconnects the stream
            return False

        # returning non-False reconnects the stream, with backoff.

# %%
auth = tweepy.OAuthHandler(TWITTER_CONSUMER_KEY, TWITTER_CONSUMER_SECRET)
auth.set_access_token(TWITTER_ACCESS_TOKEN, TWITTER_ACCESS_TOKEN_SECRET)

# %%
myStreamListener = MyStreamListener()
myStream = tweepy.Stream(auth = api.auth, listener=myStreamListener)

# %%
myStream.filter(track=['#RoyalWedding'])
# Out:
# RT @YsabellaGrace_: Fam look at the way he’s just mesmerised by her. Lord. https://t.co/f0R3NfkVG7
# RT @AryElDiablo: Comparte esta Victoria Beckham de la suerte para que tengas su mirada fulminante cada vez que otras voltean a ver a tu mac…
# RT @aai_luv_uuu: Bagum uski Shadi uski maza uska tu Beach main ungli karna wala kn ;")  #ARY #DUNIYA #GEO #SAMMA
# #RoyalWedding
# RT @rachellord22: Americans tweeting about the royal wedding be like https://t.co/KPobg8N1bP
# RT @RoyalFamily: Karen Gibson and @TheKingdomChoir sing "Stand by me" from the West End of the Chapel #RoyalWedding https://t.co/1T4i0SNOnV
# RT @YsabellaGrace_: Fam look at the way he’s just mesmerised by her. Lord. https://t.co/f0R3NfkVG7
# RT @mtrsrr: บอกตรงๆคือครั้งแรกที่เห็นหลงในความน่ารัก น่ารักเกินไปแล้ว ♡ #RoyalWedding https://t.co/7tq8GuN1Gv
# RT @jorgeerva: Me voy a ir a tomar fotos afuera de tu casa a ver si me pasa lo mismo https://t.co/iaT0aNoF6g
# RT @krystalpnss: อามาล อลามุดดิน เพิ่งรู้จักอามาลจากงานเจ้าชายแฮร์รี่ ไปลองหาประวัติเธออ่าน โคตรทึ่งงงง เป็นผญ.ที่เก่งมากๆ #RoyalWedding ht…
# RT @scamberrose: Okay but Meghan Markle didn’t bring out the pink Lamborghini just to race with Chyna and take her wraith to China just to…
# RT @hantbent: “the photographer”s name is Alexi Lubomirski. let’s give credit where it’s due. i can only imagine what it’s like to see ever…
# RT @NotScottInSC: Larry can say this because he’s black. I can’t say this because I’m white. Sad! https://t.co/cqo6NAsEdZ
# RT @OhSo100m: Black don't crack. https://t.co/aqyHSyoe4e
# RT @mtrsrr: บอกตรงๆคือครั้งแรกที่เห็นหลงในความน่ารัก น่ารักเกินไปแล้ว ♡ #RoyalWedding https://t.co/7tq8GuN1Gv
# RT @scamberrose: Okay but Meghan Markle didn’t bring out the pink Lamborghini just to race with Chyna and take her wraith to China just to…
# RT @YsabellaGrace_: Fam look at the way he’s just mesmerised by her. Lord. https://t.co/f0R3NfkVG7
# RT @scamberrose: Okay but Meghan Markle didn’t bring out the pink Lamborghini just to race with Chyna and take her wraith to China just to…
# RT @jorgeerva: Me voy a ir a tomar fotos afuera de tu casa a ver si me pasa lo mismo https://t.co/iaT0aNoF6g
# RT @adamlea2: Let’s take a moment to honor this beautiful, strong woman; Meghan Markle’s Mother, Doria Ragland, who sat alone, a million mi…
# RT @LondonaLozzy: Diana, your son got married today. The flowers in Meghan's bouquet were hand picked by him from your garden. The hymn the…
# RT @YsabellaGrace_: Fam look at the way he’s just mesmerised by her. Lord. https://t.co/f0R3NfkVG7
# RT @starIighttswift: Y luego encima dice "I'm so lucky", es que en serio, dónde puedo encontrar un hombre así?
#
# #RoyalWedding
#  https://t.c…
# RT @Y2SHAF: inviting your ex to your wedding is top tier savagery https://t.co/IfOZaGg7Vi
# RT @jorgeerva: Me voy a ir a tomar fotos afuera de tu casa a ver si me pasa lo mismo https://t.co/iaT0aNoF6g
# RT
# RT @palapang: ไปอ่าน facts เกี่ยวกับ #RoyalWedding  มาแล้วเห็นว่าน่าสนใจดี คือนอกจากเพลง Hymn ที่บรรเลงในงานศพเจ้าหญิงไดอาน่าจะถูกบรรเลงในง…
# RT @yicaichina: The latest Yicai Global  - China Business News! https://t.co/fQ7EwD81NZ Thanks to @asia_active #royalwedding
# @kron4news Warriors - Houston #WarriorsGround #DubNation #rockets #runasone #BBMAs #RoyalWedding https://t.co/F4k0VQn3mS
# RT @queenbbpp: อีกคนที่โดดเด่นในงาน #Royalwedding
# เราชอบมากเป็นการส่วนตัว ไอดอลเราเลยคือ Amal Clooney ภรรยาของ George Clooney ประวัติดีกรี…
# RT @kathleen_hanley: my favorite moment of the day #RoyalWedding https://t.co/rDWgyhX0c6
# RT @YuiMok: Thanks, glad you like the photo. It was taken by myself, and I'm a staff photographer for @PA based in the UK. I was positioned…
# RT @rachellord22: Americans tweeting about the royal wedding be like https://t.co/KPobg8N1bP
# RT @scamberrose: Okay but Meghan Markle didn’t bring out the pink Lamborghini just to race with Chyna and take her wraith to China just to…
# RT @hannahbsampson: This moment was straight out of a movie. #RoyalWedding https://t.co/wEtr51DX2O
# RT @kyalbr: "Open the door for her. Then you let her get in. Then you close the door. Then you walk around the back of the car and look thr…
# RT @NamwanAgain: #RoyalWedding
# ถึงเป็นคนไม่ค่อยรับข่าวสารก็ควรรู้เรื่องไว้หน่อยป้ะ อย่างวันนี้เพื่อนมาถามว่าคนที่แต่งงานเค้าคือใคร
# คือแดก…
# RT @rachellord22: Americans tweeting about the royal wedding be like https://t.co/KPobg8N1bP
# RT @aracecago: Mbore que me voy a ir al casamiento de mi ex https://t.co/kxzYXOjG2k
# RT @eufeoliveira: Pelo visto o Príncipe Charles teve mais tempo que os filhos para colher as flores pro buquê 💐
# #RoyalWedding
# #CasamentoRea…
# RT @drizzyxcole: this the Royal Wedding not a Love and Hip Hop special https://t.co/gdvjTsLTX7
# RT @akorsh9: I was asked to write something for The New York Daily News, they were kind enough to print some of it.  Here’s the rest... #Ro…
# RT @tucasloledo: Prince Harry at the afterparty #RoyalWedding https://t.co/58imgq077k
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-86b636e34d74> in <module>()
# ----> 1 myStream.filter(track=['#RoyalWedding'])
#
# C:\Users\sukmawicaksana\Anaconda2\envs\DSTalk-Astra\lib\site-packages\tweepy\streaming.pyc in filter(self, follow, track, async, locations, stall_warnings, languages, encoding, filter_level)
#     448         self.session.params = {'delimited': 'length'}
#     449         self.host = 'stream.twitter.com'
# --> 450         self._start(async)
#     451
#     452     def sitestream(self, follow, stall_warnings=False,
#
# C:\Users\sukmawicaksana\Anaconda2\envs\DSTalk-Astra\lib\site-packages\tweepy\streaming.pyc in _start(self, async)
#     362             self._thread.start()
#     363         else:
# --> 364             self._run()
#     365
#     366     def on_closed(self, resp):
#
# C:\Users\sukmawicaksana\Anaconda2\envs\DSTalk-Astra\lib\site-packages\tweepy\streaming.pyc in _run(self)
#     264                     self.snooze_time = self.snooze_time_step
#     265                     self.listener.on_connect()
# --> 266                     self._read_loop(resp)
#     267             except (Timeout, ssl.SSLError) as exc:
#     268                 # This is still necessary, as a SSLError can actually be
#
# C:\Users\sukmawicaksana\Anaconda2\envs\DSTalk-Astra\lib\site-packages\tweepy\streaming.pyc in _read_loop(self, resp)
#     314             length = 0
#     315             while not resp.raw.closed:
# --> 316                 line = buf.read_line().strip()
#     317                 if not line:
#     318                     self.listener.keep_alive()  # keep-alive new lines are expected
#
# C:\Users\sukmawicaksana\Anaconda2\envs\DSTalk-Astra\lib\site-packages\tweepy\streaming.pyc in read_line(self, sep)
#     179             else:
#     180                 start = len(self._buffer)
# --> 181             self._buffer += self._stream.read(self._chunk_size)
#     182         return six.b('')
#     183
#
# C:\Users\sukmawicaksana\Anaconda2\envs\DSTalk-Astra\lib\site-packages\urllib3\response.pyc in read(self, amt, decode_content, cache_content)
#     382             else:
#     383                 cache_content = False
# --> 384                 data = self._fp.read(amt)
#     385                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     386                     # Close the connection when no data is returned
#
# C:\Users\sukmawicaksana\Anaconda2\envs\DSTalk-Astra\lib\httplib.pyc in read(self, amt)
#     571
#     572         if self.chunked:
# --> 573             return self._read_chunked(amt)
#     574
#     575         if amt is None:
#
# C:\Users\sukmawicaksana\Anaconda2\envs\DSTalk-Astra\lib\httplib.pyc in _read_chunked(self, amt)
#     613         while True:
#     614             if chunk_left is None:
# --> 615                 line = self.fp.readline(_MAXLINE + 1)
#     616                 if len(line) > _MAXLINE:
#     617                     raise LineTooLong("chunk size")
#
# C:\Users\sukmawicaksana\Anaconda2\envs\DSTalk-Astra\lib\socket.pyc in readline(self, size)
#     478             while True:
#     479                 try:
# --> 480                     data = self._sock.recv(self._rbufsize)
#     481                 except error, e:
#     482                     if e.args[0] == EINTR:
#
# C:\Users\sukmawicaksana\Anaconda2\envs\DSTalk-Astra\lib\site-packages\urllib3\contrib\pyopenssl.pyc in recv(self, *args, **kwargs)
#     268                 raise
#     269         except OpenSSL.SSL.WantReadError:
# --> 270             rd = util.wait_for_read(self.socket, self.socket.gettimeout())
#     271             if not rd:
#     272                 raise timeout('The read operation timed out')
#
# C:\Users\sukmawicaksana\Anaconda2\envs\DSTalk-Astra\lib\site-packages\urllib3\util\wait.pyc in wait_for_read(socks, timeout)
#      31     or optionally a single socket if passed in. Returns a list of
#      32     sockets that can be read from immediately. """
# ---> 33     return _wait_for_io_events(socks, EVENT_READ, timeout)
#      34
#      35
#
# C:\Users\sukmawicaksana\Anaconda2\envs\DSTalk-Astra\lib\site-packages\urllib3\util\wait.pyc in _wait_for_io_events(socks, events, timeout)
#      24             selector.register(sock, events)
#      25         return [key[0].fileobj for key in
# ---> 26                 selector.select(timeout) if key[1] & events]
#      27
#      28
#
# C:\Users\sukmawicaksana\Anaconda2\envs\DSTalk-Astra\lib\site-packages\urllib3\util\selectors.pyc in select(self, timeout)
#     318             ready = []
#     319             r, w, _ = _syscall_wrapper(self._select, True, self._readers,
# --> 320                                        self._writers, timeout)
#     321             r = set(r)
#     322             w = set(w)
#
# C:\Users\sukmawicaksana\Anaconda2\envs\DSTalk-Astra\lib\site-packages\urllib3\util\selectors.pyc in _syscall_wrapper(func, recalc_timeout, *args, **kwargs)
#      92         while result is _SYSCALL_SENTINEL:
#      93             try:
# ---> 94                 result = func(*args, **kwargs)
#      95             # OSError is thrown by select.select
#      96             # IOError is thrown by select.epoll.poll
#
# C:\Users\sukmawicaksana\Anaconda2\envs\DSTalk-Astra\lib\site-packages\urllib3\util\selectors.pyc in _select(self, r, w, timeout)
#     308         def _select(self, r, w, timeout=None):
#     309             """ Wrapper for select.select because timeout is a positional arg """
# --> 310             return select.select(r, w, [], timeout)
#     311
#     312         def select(self, timeout=None):
#
# KeyboardInterrupt:
