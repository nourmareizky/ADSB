# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
imdb = pd.read_csv("IMDB.csv",encoding='latin1')

# %%
imdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3781 entries, 0 to 3780
# Data columns (total 36 columns):
# movie_ID                     3781 non-null int64
# movie_title                  3781 non-null object
# duration                     3781 non-null int64
# color                        3781 non-null int64
# title_year                   3781 non-null int64
# country                      3781 non-null object
# language                     3781 non-null object
# content_rating               3781 non-null object
# budget_USD                   3781 non-null int64
# gross_USD                    3781 non-null int64
# net_USD                      3781 non-null int64
# profitable                   3781 non-null int64
# director_name                3781 non-null object
# director_top20               3781 non-null int64
# director_facebook            3781 non-null int64
# director_facebook_likes      3781 non-null int64
# actor_1_name                 3781 non-null object
# ...

# %%
imdb.head(5)
# Out:
#    movie_ID                               movie_title  duration  color  \
# 0         1                                    Avatar       178      1
# 1         2  Pirates of the Caribbean: At World's End       169      1
# 2         3                     The Dark Knight Rises       164      1
# 3         4                              Spider-Man 3       156      1
# 4         5        Batman v Superman: Dawn of Justice       183      1
#
#    title_year country language content_rating  budget_USD  gross_USD  \
# 0        2009     USA  English          PG-13   237000000  760505847
# 1        2007     USA  English          PG-13   300000000  309404152
# 2        2012     USA  English          PG-13   250000000  448130642
# 3        2007     USA  English          PG-13   258000000  336530303
# 4        2016     USA  English          PG-13   250000000  330249062
#
#        ...       actor_3_facebook  actor_3_facebook_likes  \
# 0      ...                      1                     855
# ...

# %%
imdb.tail(5)
# Out:
#       movie_ID         movie_title  duration  color  title_year country  \
# 3776      3777      New Year's Eve       113      1        2011     USA
# 3777      3778       Boogie Nights       155      1        1997     USA
# 3778      3779  Battle of the Year       110      1        2013     USA
# 3779      3780          The Master       144      1        2012     USA
# 3780      3781  500 Days of Summer        95      1        2009     USA
#
#      language content_rating  budget_USD  gross_USD      ...       \
# 3776  English          PG-13    56000000   54540525      ...
# 3777  English              R    15000000   26384919      ...
# 3778  English          PG-13    20000000    8888355      ...
# 3779  English              R    32000000   16377274      ...
# 3780  English          PG-13     7500000   32391374      ...
#
#       actor_3_facebook  actor_3_facebook_likes cast_total_facebook_likes  \
# 3776                 1                     307                     23456
# ...

# %%
imdb.shape
# Out:
# (3781, 36)

# %%
imdb[max(imdb['imdb_score'])
# Out:
# 9.3

# %% [markdown]
# # 1

# %%
imdb[(imdb.imdb_score == 9.3)]
# Out:
#      movie_ID               movie_title  duration  color  title_year country  \
# 746       747  The Shawshank Redemption       142      1        1994     USA
#
#     language content_rating  budget_USD  gross_USD      ...       \
# 746  English              R    25000000   28341469      ...
#
#      actor_3_facebook  actor_3_facebook_likes cast_total_facebook_likes  \
# 746                 1                     461                     13495
#
#      movie_facebook  movie_facebook_likes  facenumber_in_poster  \
# 746               1                108000                     0
#
#     num_voted_users  num_user_for_reviews  imdb_score  imdb_top_250
# 746         1689764                  4144         9.3             1
#
# [1 rows x 36 columns]

# %%
imdb[['movie_title','imdb_score']].sort_values(by=['imdb_score'],ascending=False).head(1)
# Out:
#                   movie_title  imdb_score
# 746  The Shawshank Redemption         9.3

# %%
imdb[(imdb.imdb_score == imdb['imdb_score'].max())]
# Out:
#      movie_ID               movie_title  duration  color  title_year country  \
# 746       747  The Shawshank Redemption       142      1        1994     USA
#
#     language content_rating  budget_USD  gross_USD      ...       \
# 746  English              R    25000000   28341469      ...
#
#      actor_3_facebook  actor_3_facebook_likes cast_total_facebook_likes  \
# 746                 1                     461                     13495
#
#      movie_facebook  movie_facebook_likes  facenumber_in_poster  \
# 746               1                108000                     0
#
#     num_voted_users  num_user_for_reviews  imdb_score  imdb_top_250
# 746         1689764                  4144         9.3             1
#
# [1 rows x 36 columns]

# %% [markdown]
# # 2

# %%
imdb[(imdb.duration == imdb['duration'].min())]
# Out:
#       movie_ID   movie_title  duration  color  title_year country language  \
# 1362      1363  Evil Dead II        37      1        1987     USA  English
#
#      content_rating  budget_USD  gross_USD      ...       actor_3_facebook  \
# 1362              X     3600000    5923044      ...                      1
#
#       actor_3_facebook_likes cast_total_facebook_likes  movie_facebook  \
# 1362                     199                      1347               0
#
#       movie_facebook_likes  facenumber_in_poster num_voted_users  \
# 1362                     0                     0          113451
#
#       num_user_for_reviews  imdb_score  imdb_top_250
# 1362                   537         7.8             0
#
# [1 rows x 36 columns]

# %% [markdown]
# # 3

# %%
imdb[(imdb.title_year == imdb['title_year'].max())]
# Out:
#       movie_ID                         movie_title  duration  color  \
# 4            5  Batman v Superman: Dawn of Justice       183      1
# 12          13          Captain America: Civil War       147      1
# 36          37                     The Jungle Book       106      1
# 41          42        Independence Day: Resurgence       120      1
# 47          48                            Warcraft       123      1
# 74          75                     Kung Fu Panda 3        95      1
# 84          85                             The BFG       117      1
# 105        106                        Jason Bourne       123      1
# 235        236             The Secret Life of Pets        87      1
# 257        258               The Angry Birds Movie        97      1
# 355        356                            Deadpool       108      1
# 409        410                            13 Hours       144      1
# 478        479                     The Conjuring 2       134      1
# ...

# %% [markdown]
# # 4

# %%
imdb[(imdb.imdb_score == imdb['imdb_score'].max()) & (imdb.country == 'USA')]
# Out:
#      movie_ID               movie_title  duration  color  title_year country  \
# 746       747  The Shawshank Redemption       142      1        1994     USA
#
#     language content_rating  budget_USD  gross_USD      ...       \
# 746  English              R    25000000   28341469      ...
#
#      actor_3_facebook  actor_3_facebook_likes cast_total_facebook_likes  \
# 746                 1                     461                     13495
#
#      movie_facebook  movie_facebook_likes  facenumber_in_poster  \
# 746               1                108000                     0
#
#     num_voted_users  num_user_for_reviews  imdb_score  imdb_top_250
# 746         1689764                  4144         9.3             1
#
# [1 rows x 36 columns]

# %%
x = imdb.groupby(['content_rating']).mean()

# %%
x['duration']
# Out:
# content_rating
# Approved     123.928571
# G             98.272727
# GP           120.000000
# M            126.000000
# NC-17        103.000000
# Not Rated    104.923077
# PG           104.806338
# PG-13        112.123570
# Passed       103.000000
# R            110.757434
# Unrated      106.958333
# X             90.800000
# Name: duration, dtype: float64

# %%
conditions = [(imdb['imdb_score'] >=6.5) , (imdb['imdb_score'] <6.5)] 
choices =['A','B']
imdb['imdb_score_group']= np.select(conditions, choices)

# %%
#imdb[['imdb_score_group']]

# %%
X = imdb[(imdb.imdb_score_group == 'A') & (imdb['director_top20'] == 1)]

# %%
Y = imdb[(imdb.imdb_score_group == 'A') & (imdb['director_top20'] == 0)]

# %%
len(Y)
# Out:
# 1860

# %%
x1 = imdb[imdb.imdb_score>=7]
x2 = imdb[imdb.imdb_score<7]
x1
# Out:
#       movie_ID                                      movie_title  duration  \
# 0            1                                           Avatar       178
# 1            2         Pirates of the Caribbean: At World's End       169
# 2            3                            The Dark Knight Rises       164
# 6            7                                     Man of Steel       143
# 7            8        The Hobbit: The Battle of the Five Armies       164
# 8            9                           The Amazing Spider-Man       153
# 10          11                                        King Kong       201
# 11          12                                          Titanic       194
# 12          13                       Captain America: Civil War       147
# 14          15                                   Jurassic World       124
# 15          16                                          Skyfall       143
# 18          19                              Monsters University       104
# ...

# %%
Dir_x1 = x1[x1.director_top20 == 1]
Dir_xx1 = x1[x1.director_top20 == 0]
Dir_x2 = x2[x2.director_top20 == 1]
print(len(Dir_x1)/len(x1)*100)
print(len(Dir_x2)/len(x2)*100)
# Out:
# 10.703125
# 6.317473010795682

# %%
Act1_x1 = x1[x1['actor_top20.1'] == 1]
Act1_xx1 = x1[x1['actor_top20.1'] == 0] 
Act1_x2 = x2[x2['actor_top20.1'] == 1]
print(len(Act1_x1)/len(x1))
print(len(Act1_x2)/len(x2))
# Out:
# 0.0484375
# 0.01919232307077169

# %%
Act2_x1 = x1[x1['actor_top20.2'] == 1]
Act2_xx1 = x1[x1['actor_top20.2'] == 0]
Act2_x2 = x2[x2['actor_top20.2'] == 1]
print(len(Act2_x1)/len(x1))
print(len(Act2_x2)/len(x2))
# Out:
# 0.01015625
# 0.0027988804478208716

# %%
sns.countplot("director_top20", hue="imdb_score_group", data=imdb)

# %%
labels = 'actor2 top 20','actor 2 not top20'  
sizes = [len(Act2_x1), len(Act2_xx1)] # my arbitrary list just for testing
colors = ['yellowgreen', 'mediumpurple'] 
plt.pie(sizes, labels=labels,colors=colors, autopct='%1.1f%%')
plt.axis('equal')
plt.show()

# %%
labels = 'actor1 top 20','actor 1 not top20'  
sizes = [len(Act1_x1), len(Act1_xx1)] # my arbitrary list just for testing
colors = ['yellowgreen', 'mediumpurple'] 
plt.pie(sizes, labels=labels,colors=colors, autopct='%1.1f%%')
plt.axis('equal')
plt.show()

# %%
labels = 'director top 20','director not top20'  
sizes = [len(Dir_x1), len(Dir_xx1)] # my arbitrary list just for testing
colors = ['yellowgreen', 'mediumpurple'] 
plt.pie(sizes, labels=labels,colors=colors, autopct='%1.1f%%')
plt.axis('equal')
plt.show()
