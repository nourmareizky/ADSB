# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('df1.csv',index_col=0)
df2 = pd.read_csv('df2.csv')
df3 = pd.read_csv('df3.csv')

# %%
df1.info()
df2
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 01-01-00 to 26-09-02
# Data columns (total 4 columns):
# A    1000 non-null float64
# B    1000 non-null float64
# C    1000 non-null float64
# D    1000 non-null float64
# dtypes: float64(4)
# memory usage: 39.1+ KB
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008
# 5  0.286043  0.593465  0.907307  0.637898
# 6  0.430436  0.166230  0.469383  0.497701
# 7  0.312296  0.502823  0.806609  0.850519
# 8  0.187765  0.997075  0.895955  0.530390
# 9  0.908162  0.232726  0.414138  0.432007

# %%
df1.head(5)
# Out:
#                  A         B         C         D
# Date
# 01-01-00  1.339091 -0.163643 -0.646443  1.041233
# 02-01-00 -0.774984  0.137034 -0.882716 -2.253382
# 03-01-00 -0.921037 -0.482943 -0.417100  0.478638
# 04-01-00 -1.738808 -0.072973  0.056517  0.015085
# 05-01-00 -0.905980  1.778576  0.381918  0.291436

# %%
df1['A'].hist(bins=20)

# %%
plt.style.use("ggplot")

# %% [markdown]
# # Area Plot

# %%
#Area Plot
df2.plot.area(alpha=0.5) #alpha mengatur opacity
df2[['a','b']].plot.area(alpha=0.8, figsize=(10,10)) #figsize mengatur ukuran canvas

# %% [markdown]
# # Bar Plot

# %%
df2.plot.bar(alpha=0.7)

# %%
x = df2[['b','c']].plot.bar(stacked=True, figsize=(8,4))

# %% [markdown]
# # Line Plots

# %%
df1.plot.line(x=df1.index, y='B',lw=0.5, figsize=(10,5))

# %% [markdown]
# # Scatter Plot

# %%
df1.plot.scatter(x='A',y='B',c='C',cmap="coolwarm") #menampilkan dimensi ketiga dgn warna

# %%
df1.plot.scatter(x='A',y='B',s=df1['C']*50) #menampilkan dimensi ketiga dnegan size
# Out:
# C:\Users\nourma059258\AppData\Local\Continuum\miniconda2\envs\py36\lib\site-packages\matplotlib\collections.py:853: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
df2['a'].plot.kde()

# %% [markdown]
# # EXERCISE

# %%
df3.plot.scatter(x='a',y='b',s=50,c="red",figsize=(10,5)).set_xlim(-0.2,1.2)
# Out:
# (-0.2, 1.2)

# %%
df3[['a','b']].plot.box()
plt.xlabel("Column")
# Out:
# Text(0.5,0,'Column')
